# %%
import pandas as pd
import numpy as np

# %%
#1.Read both Datasets and Make copies of train_jobs and test_jobs dataset.
df=pd.read_csv('test_jobs.csv')
df1=pd.read_csv('train_jobs.csv')

# %%
d1=df.copy()
d1
# Out:
#                                              Job Title Salary Estimate  \
# 0                                    Sr Data Scientist        137-171
# 1                                       Data Scientist        137-171
# 2                                       Data Scientist        137-171
# 3                                       Data Scientist        137-171
# 4                                       Data Scientist        137-171
# 5                                       Data Scientist        137-171
# 6             Data Scientist / Machine Learning Expert        137-171
# 7                                       Data Scientist        137-171
# 8                     Staff Data Scientist - Analytics        137-171
# 9                                       Data Scientist        137-171
# 10                                      Data Scientist        137-171
# 11                                      Data Scientist        137-171
# ...

# %%
d2=df.copy()
d2
# Out:
#                                              Job Title Salary Estimate  \
# 0                                    Sr Data Scientist        137-171
# 1                                       Data Scientist        137-171
# 2                                       Data Scientist        137-171
# 3                                       Data Scientist        137-171
# 4                                       Data Scientist        137-171
# 5                                       Data Scientist        137-171
# 6             Data Scientist / Machine Learning Expert        137-171
# 7                                       Data Scientist        137-171
# 8                     Staff Data Scientist - Analytics        137-171
# 9                                       Data Scientist        137-171
# 10                                      Data Scientist        137-171
# 11                                      Data Scientist        137-171
# ...

# %%
#2. Describe the details of both the datasets
df.describe()
# Out:
#            Rating  min_salary  max_salary  avg_salary  same_state  \
# count  660.000000  660.000000  660.000000  660.000000  660.000000
# mean     3.587424   99.296970  148.301515  123.612121    0.407576
# std      1.183540   33.161485   48.264588   39.786698    0.491756
# min      0.000000   31.000000   56.000000   43.000000    0.000000
# 25%      3.300000   79.000000  119.000000  103.000000    0.000000
# 50%      3.800000   91.000000  133.000000  114.000000    0.000000
# 75%      4.300000  122.000000  165.000000  136.000000    1.000000
# max      5.000000  212.000000  331.000000  271.000000    1.000000
#
#        company_age      python       excel      hadoop       spark  \
# count   660.000000  660.000000  660.000000  660.000000  660.000000
# mean     29.736364    0.730303    0.440909    0.212121    0.281818
# std      39.763033    0.444139    0.496873    0.409120    0.450226
# min      -1.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
df1.describe()
# Out:
#            Rating      Founded
# count  672.000000   672.000000
# mean     3.518601  1635.529762
# std      1.410329   756.746640
# min     -1.000000    -1.000000
# 25%      3.300000  1917.750000
# 50%      3.800000  1995.000000
# 75%      4.300000  2009.000000
# max      5.000000  2019.000000

# %%
#3. Get the size of both the dataframes
df.size
# Out:
# 17820

# %%
df1.size
# Out:
# 9408

# %%
#4. Combine the train_jobs and test_jobs dataset to seperate data
d=pd.concat([df1,df])
d
# Out:
# D:\python\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app
#                                     Company Name  \
# 0                               Healthfirst\n3.1
# 1                                   ManTech\n4.2
# 2                            Analysis Group\n3.8
# 3                                   INFICON\n3.5
# 4                        Affinity Solutions\n2.9
# 5                               HG Insights\n4.2
# 6                                  Novartis\n3.9
# 7                                    iRobot\n3.5
# 8                             Intuit - Data\n4.4
# 9                        XSELL Technologies\n3.6
# 10                                  Novetta\n4.5
# ...

# %%
#5. Show the histogram based on rating for 20 bins of train_jobs.
# %matplotlib inline
df1[['Rating']].hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1114FF90>]],
#       dtype=object)

# %%
#6. Plot bar graph and Pie chart for the rating count of combined dataset.
d['Rating'].value_counts().hist(bins=20,width=5)

# %%
a=d['Rating'].value_counts().plot(kind='bar')
a

# %%
#7. Get the Different types of job_state counts available in the test_jobs and plot bar graph.
import matplotlib.pyplot as plt
a=df['job_state'].unique()
b=df['job_state'].value_counts()
plt.figure(figsize=(20, 10))
plt.bar(a, b,width = 0.4)
# Out:
# <BarContainer object of 39 artists>

# %%
#8. Get the Different types of Job Title that are first five highest counts available in the combined dataset .
a=d['Job Title'].value_counts().nlargest(5)
a
# Out:
# Data Scientist               670
# Data Engineer                 52
# Senior Data Scientist         38
# Machine Learning Engineer     30
# Data Analyst                  24
# Name: Job Title, dtype: int64

# %%
#9. Plot bar graph for the above counts.
a=d['Job Title'].value_counts().nlargest(5)
a.plot(kind='bar')

# %%
#10.list of 5 compaanies with highest revenue

d['Revenue'].value_counts().nlargest(5)
# Out:
# Unknown / Non-Applicable      419
# $100 to $500 million (USD)    188
# $10+ billion (USD)            125
# $2 to $5 billion (USD)         90
# $10 to $25 million (USD)       81
# Name: Revenue, dtype: int64

# %%
#11.list of 10 compaanies with highest rating
r2=d.nlargest(10,'Rating')
r2
# Out:
#                          Company Name Competitors  Founded  \
# 32                 Cohere Health\n5.0          -1   2019.0
# 43           Arsenal Biosciences\n5.0          -1   2019.0
# 113                   Phantom AI\n5.0          -1   2016.0
# 118          Arsenal Biosciences\n5.0          -1   2019.0
# 130                  Notion Labs\n5.0          -1   2016.0
# 144  Expedition Technology, Inc.\n5.0          -1   2013.0
# 193                   SkillSoniq\n5.0          -1     -1.0
# 209     Phoenix Operations Group\n5.0          -1   2011.0
# 212     Phoenix Operations Group\n5.0          -1   2011.0
# 227                          REE\n5.0          -1   2018.0
#
#                 Headquarters                                 Industry  \
# 32                Boston, MA                              IT Services
# 43   South San Francisco, CA                Biotech & Pharmaceuticals
# 113           Burlingame, CA             Computer Hardware & Software
# ...

# %%
#12 . maximum salary of test_jobs dataset
m=df['max_salary'].max()
m
# Out:
# 331

# %%
#13. minimum  salary of test_jobs dataset

n=df['min_salary'].min()
n
# Out:
# 31

# %%
#14. list of 10 companies with highest salary of test_jobs dataset
r=df.nlargest(10,'max_salary')
r
# Out:
#                                              Job Title Salary Estimate  \
# 499         Senior Principal Data Scientist (Python/R)        212-331
# 500                 Real World Science, Data Scientist        212-331
# 501                                     Data Scientist        212-331
# 502        Data Scientist(s)/Machine Learning Engineer        212-331
# 503                              Senior Data Scientist        212-331
# 504                                     Data Scientist        212-331
# 505                                     Data Scientist        212-331
# 506                                     Data Scientist        212-331
# 507  ENGINEER - COMPUTER SCIENTIST - RESEARCH COMPU...        212-331
# 508                                     Data Scientist        212-331
#
#                                        Job Description  Rating  \
# 499  Roche Diagnostics has built a new strategic ar...     4.1
# 500  Title: Real World Science, Data Scientist\nLoc...     4.0
# ...

# %%
#15. display the unique job titles of test_dataset

df['Job Title'].unique()
# Out:
# array(['Sr Data Scientist', 'Data Scientist',
#        'Data Scientist / Machine Learning Expert',
#        'Staff Data Scientist - Analytics',
#        'Data Scientist - Statistics, Early Career', 'Data Modeler',
#        'Experienced Data Scientist', 'Data Analyst II',
#        'Medical Lab Scientist', 'Data Scientist/Machine Learning',
#        'Human Factors Scientist',
#        'Business Intelligence Analyst I- Data Insights',
#        'Data Scientist - Risk', 'Data Scientist-Human Resources',
#        'Senior Research Statistician- Data Scientist', 'Data Engineer',
#        'Associate Data Scientist', 'Business Intelligence Analyst',
#        'Senior Analyst/Data Scientist', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst I',
#        'Scientist - Molecular Biology',
#        'Computational Scientist, Machine Learning',
#        'Senior Data Scientist', 'E-Commerce Data Analyst',
#        'Data Analytics Engineer',
# ...

# %%
#16. Display the unique sectors of train_dataset

#1df1['Sector'].unique()

# %%
#17. Display the total count of location from train_dataset and display histogram graph
b=df1['Location'].value_counts()
b
# Out:
# San Francisco, CA          69
# New York, NY               50
# Washington, DC             26
# Boston, MA                 24
# Chicago, IL                22
# Herndon, VA                21
# Cambridge, MA              18
# McLean, VA                 12
# Chantilly, VA              11
# United States              11
# Santa Clara, CA             9
# Reston, VA                  8
# Saint Louis, MO             8
# San Diego, CA               7
# Gaithersburg, MD            7
# Redwood City, CA            7
# Atlanta, GA                 7
# Fort Belvoir, VA            6
# Cincinnati, OH              6
# Remote                      6
# Baltimore, MD               5
# Annapolis Junction, MD      5
# Falls Church, VA            5
# Thousand Oaks, CA           5
# Seattle, WA                 5
# Denver, CO                  5
# Palo Alto, CA               5
# Raleigh, NC                 4
# San Carlos, CA              4
# South San Francisco, CA     4
#                            ..
# ...

# %%
b.plot(kind='hist')

# %%
#18 List all the company name whose sector is Business Services from test_datset

for i in range(len(df)):
    if df['Sector'][i]=="Business Services":
        print(df['Company Name'])
# Out:
# 0                                 Healthfirst
# 1                                     ManTech
# 2                              Analysis Group
# 3                                     INFICON
# 4                          Affinity Solutions
# 5                                 HG Insights
# 6                                    Novartis
# 7                                      iRobot
# 8                               Intuit - Data
# 9                          XSELL Technologies
# 10                                    Novetta
# 11                                   1904labs
# 12                                       PNNL
# 13                       Old World Industries
# 14                Mathematica Policy Research
# 15       Guzman & Griffin Technologies (GGTI)
# 16                                    Buckman
# 17                  Insight Enterprises, Inc.
# 18                               Tower Health
# 19                                 Triplebyte
# ...

# %%
#19. List all the company name whose sector is Manufacturing from test_datset

for i in range(len(df)):
    if df['Sector'][i]=="Manufacturing":
        print(df['Company Name'])
# Out:
# 0                                 Healthfirst
# 1                                     ManTech
# 2                              Analysis Group
# 3                                     INFICON
# 4                          Affinity Solutions
# 5                                 HG Insights
# 6                                    Novartis
# 7                                      iRobot
# 8                               Intuit - Data
# 9                          XSELL Technologies
# 10                                    Novetta
# 11                                   1904labs
# 12                                       PNNL
# 13                       Old World Industries
# 14                Mathematica Policy Research
# 15       Guzman & Griffin Technologies (GGTI)
# 16                                    Buckman
# 17                  Insight Enterprises, Inc.
# 18                               Tower Health
# 19                                 Triplebyte
# ...

# %%
 #20.List all the company name whose industry is Consulting from train_datset

for i in range(len(df1)):
    if df1['Industry'][i]=="Consulting":
        print(df['Company Name'])
# Out:
# 0                                 Healthfirst
# 1                                     ManTech
# 2                              Analysis Group
# 3                                     INFICON
# 4                          Affinity Solutions
# 5                                 HG Insights
# 6                                    Novartis
# 7                                      iRobot
# 8                               Intuit - Data
# 9                          XSELL Technologies
# 10                                    Novetta
# 11                                   1904labs
# 12                                       PNNL
# 13                       Old World Industries
# 14                Mathematica Policy Research
# 15       Guzman & Griffin Technologies (GGTI)
# 16                                    Buckman
# 17                  Insight Enterprises, Inc.
# 18                               Tower Health
# 19                                 Triplebyte
# ...

# %%
#21. Find companies with ratings between 4.8 and 5
r=d['Rating'].between(4.8,5,inclusive = True)
p=d[r]
p
# Out:
#                          Company Name  \
# 32                 Cohere Health\n5.0
# 33              Acuity Insurance\n4.8
# 43           Arsenal Biosciences\n5.0
# 46                       Klaviyo\n4.8
# 50              Giving Assistant\n4.8
# 53                   IT Concepts\n4.8
# 74           New England Biolabs\n4.9
# 83               The Mom Project\n4.9
# 88                       Klaviyo\n4.8
# 100                       Avlino\n4.9
# 111               Big Huge Games\n4.9
# 113                   Phantom AI\n5.0
# 118          Arsenal Biosciences\n5.0
# 119               GetWellNetwork\n4.8
# 130                  Notion Labs\n5.0
# 131                       Lendio\n4.9
# 136                       Lendio\n4.9
# 139                     AppLovin\n4.8
# 144  Expedition Technology, Inc.\n5.0
# 193                   SkillSoniq\n5.0
# 209     Phoenix Operations Group\n5.0
# 212     Phoenix Operations Group\n5.0
# 213                      Klaviyo\n4.8
# ...
